# %%
from tkinter import *
import tkinter as tk 
from tkinter import messagebox 
window=Tk()
#this defines the height or width of the window
window.geometry("700x1000")
#this is the mechanism for the app
def calculate(window):
    Jollof_Rice=e1.get()
    Coconut_Fried_rice=e2.get()
    Jollof_spaghetti=e3.get()
    Savoury_Beans=e4.get()
    Roasted_sweet_potato=e5.get()
    Fried_Plantain=e6.get()
    Mixed_Vegetable_Salad=e7.get()
    Boiled_Yam=e8.get()
    Eba=e9.get()
    Poundo_Yam=e10.get()
    Atama_Soup=e11.get()
    Egusi_Soup=e12.get()
    Sweet_Chili_Chicken=e13.get()
    Grilled_Chicken_Wings=e14.get()
    Fried_Beef=e15.get()
    Fried_fish=e16.get()
    Boiled_Eggs=e17.get()
    Sauteed_Sausages=e18.get() 
    Water=e19.get()
    Glass_Drink=e20.get()
    PET_Drink=e21.get()
    PET_Drink_big=e22.get()
    canned_Malt=e23.get()
    Fresh_YO=e24.get()
    Pineapple_Juice=e25.get()
    Mango_Juice=e26.get()
    Zobo_Drink=e27.get()
    Semo_food=e28.get()
# to get the total
    total=((int(Jollof_Rice)*350)+(int(Coconut_Fried_rice)*350)+(int(Jollof_spaghetti)*350)+(int(Savoury_Beans)*350)+(int(Roasted_sweet_potato)*300)+
           (int(Fried_Plantain)*150)+(int(Mixed_Vegetable_Salad)*150)+(int(Boiled_Yam)*150)+(int(Eba)*100)+(int(Poundo_Yam)*100)+(int(Semo_food)*100)+
           (int(Atama_Soup)*450)+(int(Egusi_Soup)*480)+(int(Sweet_Chili_Chicken)*1100)+(int(Grilled_Chicken_Wings)*400)+(int(Fried_Beef)*400)+
           (int(Fried_fish)*500)+(int(Boiled_Eggs)*200)+(int(Sauteed_Sausages)*200)+(int(Water)*200)+(int(Glass_Drink)*150)+(int(PET_Drink)*150)+
           (int(PET_Drink_big)*350)+(int(canned_Malt)*500)+(int(Fresh_YO)*600)+(int(Pineapple_Juice)*350)+(int(Mango_Juice)*350)+(int(Zobo_Drink)*350))

    if total>1000 and total<2500:
       total = total-total*0.10
       messagebox.showinfo("discount received","you have recieved a 10% discount")
        
    elif total>2500 and total<5000:
         total=total-total*0.15 
         messagebox.showinfo("discount received","you have recieved a 15% discount") 
    elif total>5000:
        total=total-total*0.25
        messagebox.showinfo("discount received","you have recieved a 25% discount") 
    else:
        print(total)

    
    
    window.withdraw()
    window2 = tk.Tk()
    window.title("Check out Box") 
    window.geometry("800x700") 
       
    label_1 = tk.Label(window2, text=f"Welcome {e200.get()}\n",font="times 18 ") 
    label_1.place(x=400,y=200) 
    
    
    #to print the total
    label100=Label(window2,text=f"your total fee is {total}" ,font="times 18 ")
    label100.place(x=560,y=200)
    window2.mainloop()


    
#now for the menu card
label1=Label(window,text="PAN-ATLANTIC CAFETERIA",font="times 24 bold")
#for the position
label1.place(x=380,y=20)

#for the username
label6=Label(window,text="username",font="times 16")
label6.place(x=50,y=80)
e200=Entry(window)
e200.place(x=150,y=85)

label2=Label(window,text="Special Discount!!!",font="times 10 normal")
label2.place(x=750,y=15)

#for the menu
label3=Label(window,text="MENU",font="times 18 underline")
label3.place(x=560,y=70)

#for the billing cycle
#RICE/PASTA
label4=Label(window,text="RICE/PASTA",font="Ariel 22 underline")
label4.place(x=40,y=120)

label5=Label(window,text=",QTY",font="times 22 underline")
label5.place(x=350,y=120)

label6=Label(window,text="Jollof Rice (#350)",font="times 12")
label6.place(x=40,y=170)
e1=Entry(window)
e1.place(x=350,y=170)

label7=Label(window,text="Coconut Fried rice(#350)",font="times 12")
label7.place(x=40,y=200)
e2=Entry(window)
e2.place(x=350,y=200)

label8=Label(window,text="Jollof spaghetti(#350)",font="times 12")
label8.place(x=40,y=230)
e3=Entry(window)
e3.place(x=350,y=230)

#FOR SIDE DISHES
label9=Label(window,text="SIDE DISHES",font="Ariel 22 underline")
label9.place(x=40,y=270)
label10=Label(window,text=",QTY",font="times 22 underline")
label10.place(x=350,y=270)

label11=Label(window,text="Savoury Beans(#350)",font="times 12")
label11.place(x=40,y=305)
e4=Entry(window)
e4.place(x=350,y=305)

label12=Label(window,text="Roasted sweet potato(#350)",font="times 12")
label12.place(x=40,y=335)
e5=Entry(window)
e5.place(x=350,y=335)

label13=Label(window,text="Fried Plantain(#150)",font="times 12")
label13.place(x=40,y=365)
e6=Entry(window)
e6.place(x=350,y=365)

label14=Label(window,text="Mixed Vegetable Salad(#150)",font="times 12")
label14.place(x=40,y=395)
e7=Entry(window)
e7.place(x=350,y=395)

label15=Label(window,text="Boiled Yam(#150)",font="times 12")
label15.place(x=40,y=425)
e8=Entry(window)
e8.place(x=350,y=425)

# for Soups and Swallows
label16=Label(window,text="SIDE DISHES",font="Ariel 22 underline")
label16.place(x=40,y=450)
label17=Label(window,text=",QTY",font="times 22 underline")
label17.place(x=350,y=450)

label18=Label(window,text="Eba (#100)",font="times 12")
label18.place(x=40,y=485)
e9=Entry(window)
e9.place(x=350,y=485)

label19=Label(window,text="Poundo Yam(#100)",font="times 12")
label19.place(x=40,y=510)
e10=Entry(window)
e10.place(x=350,y=510)

label20=Label(window,text="Atama Soup(#450)",font="times 12")
label20.place(x=40,y=540)
e11=Entry(window)
e11.place(x=350,y=540)

label21=Label(window,text="Egusi Soup(#450)",font="times 12")
label21.place(x=40,y=570)
e12=Entry(window)
e12.place(x=350,y=570)

label21=Label(window,text="semo(#100)",font="times 12")
label21.place(x=40,y=600)
e28=Entry(window)
e28.place(x=350,y=600)

# FOR PROTEINS
label22=Label(window,text="PROTEINS",font="Ariel 22 underline")
label22.place(x=700,y=120)
label22=Label(window,text=",QTY",font="times 22 underline")
label22.place(x=980,y=120)

label23=Label(window,text="Sweet Chili Chicken(#1100)",font="times 12")
label23.place(x=700,y=160)
e13=Entry(window)
e13.place(x=980,y=160)

label24=Label(window,text="Grilled Chicken Wings(#400)",font="times 12")
label24.place(x=700,y=190)
e14=Entry(window)
e14.place(x=980,y=190)

label25=Label(window,text="Fried Beef(#400)",font="times 12")
label25.place(x=700,y=220)
e15=Entry(window)
e15.place(x=980,y=220)

label26=Label(window,text="Fried fish(#500)",font="times 12")
label26.place(x=700,y=250)
e16=Entry(window)
e16.place(x=980,y=250)

label27=Label(window,text="Boiled Eggs(#200)",font="times 12")
label27.place(x=700,y=280)
e17=Entry(window)
e17.place(x=980,y=280)

label28=Label(window,text="Sauteed Sausages(#200)",font="times 12")
label28.place(x=700,y=310)
e18=Entry(window)
e18.place(x=980,y=310)

#BEVERAGES
label29=Label(window,text="BEVERAGES",font="Ariel 22 underline")
label29.place(x=700,y=340)
label30=Label(window,text=",QTY",font="times 22 underline")
label30.place(x=980,y=340)

label31=Label(window,text="Water(#200)",font="times 12")
label31.place(x=700,y=380)
e19=Entry(window)
e19.place(x=980,y=380)

label32=Label(window,text="Glass Drink 35cl (#200)",font="times 12")
label32.place(x=700,y=410)
e20=Entry(window)
e20.place(x=980,y=410)

label33=Label(window,text="PET Drink(35cl)(#200)",font="times 12")
label33.place(x=700,y=440)
e21=Entry(window)
e21.place(x=980,y=440)

label34=Label(window,text="PET Drink(50cl)(#200)",font="times 12")
label34.place(x=700,y=470)
e22=Entry(window)
e22.place(x=980,y=470)

label35=Label(window,text="Glass/canned Malt(#500)",font="times 12")
label35.place(x=700,y=500)
e23=Entry(window)
e23.place(x=980,y=500)

label36=Label(window,text="Fresh YO(#600)",font="times 12")
label36.place(x=700,y=530)
e24=Entry(window)
e24.place(x=980,y=530)

label37=Label(window,text="Pineapple Juice(#350) ",font="times 12")
label37.place(x=700,y=560)
e25=Entry(window)
e25.place(x=980,y=560)

label38=Label(window,text="Mango Juice(#350)",font="times 12")
label38.place(x=700,y=590)
e26=Entry(window)
e26.place(x=980,y=590)

label39=Label(window,text="Zobo Drink(#350)",font="times 12")
label39.place(x=700,y=620)
e27=Entry(window)
e27.place(x=980,y=620)

b2=Button(window,text='Order',width=10,command=lambda : calculate(window))
b2.place(x=560,y=140)
label40=Label(window,text="NOTE : input 0 for those you do not want",font="times 10 underline")
label40.place(x=10,y=10)

label41=Label(window,text="CLICK on 'TABS for faster navigation'",font="times 10 underline")
label41.place(x=10,y=30)

window.mainloop()
