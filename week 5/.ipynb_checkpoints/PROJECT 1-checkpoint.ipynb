# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk


def welcomeMessage(username):
    #create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("800x400")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This are the other members of your department")
    label_2.pack()
    label_3 = tk.Label(window, text="Adeniran oluwatamilore\n" "Agbakwuru chiemeziem\n" "Arnika osose\n" "Chukuma Nedi\n" "Ezeonye makuochukwu\n" "Giwa moyosore\n" "Nwokolo chijindu\n" "Nwokolo joseph\n" "Okoro Derek\n" "Peter owoede")
    label_3.pack()

    # run the tkinter event loop
    

def welcomeMessage(username1):
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("800x400")

    label_1 = tk.Label(window, text=f"Welcome {username1}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This are the other members of your department")
    label_2.pack()
    label_3 = tk.Label(window, text="ADEWUMI Ayomide\n" "AGBAKURU- NWOGU Chukwunonye\n" "AKINDE Oluwatimehin\n" "Ebi Stephanie\n" "ICHA Ayonete\n" "IKPATI Eche\n" "OBASOGIE Daisy\n" "OBI Samuel\n" "OBIALOR Betha\n" "OLOWOKERE Akorede\n" "OLUBUADE Rasheed\n" "OSEMEKE Daniel") 
    label_3.pack()
   

def welcomeMessage(username2):
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("800x400")

    label_1 = tk.Label(window, text=f"Welcome {username2}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This are the other members of your department")
    label_2.pack()
    label_3 = tk.Label(window, text="ADOH-AJAGBE Oshim\n" "ATELLY Daniel\n" "AZOGU Onyekachi/n" "BETURE Shalom\n" "EJEDIMU Edward\n" "ILOENYOSI Michael\n" "IYAWE Oluwadamilola\n" "OGBONNA Boluwatife\n" "OIGBOCHIE Mary\n" "QUADRI Oluwafikunmi/n" "UDE-IBE Uchenna") 
    label_3.pack()
    
  

def welcomeMessage(username3):
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("800x400")

    label_1 = tk.Label(window, text=f"Welcome {username3}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This are the other members of your department")
    label_2.pack()
    label_3 = tk.Label(window, text="EGBORO Jason\n" "ELERI Otu\n" "EZE Onyinyechi\n" "OKOCHA-OJEAH Raphael\n" "OKOLO Victor\n" "UMEH Ejike"  ) 
    label_3.pack()
   
  

def submit():
    username = username_entry.get()
    password = password_entry.get()

    if username == "Oluwatamilore" or "Chiemeziem" or "Osose" or "Nedi" or "Makuochukwu" or "Moyosore" or "Chijindu" or "Joseph" or "Derek" or "Owoede" or "Mary-cynthia"  and password == "Logistics":
        welcomeMessage(username)
    elif username1 == "Ayomide" or "Chukwunonye" or "Oluwatimehin" or "Stephanie" or "Ayonete" or "Eche" or "Daisy" or "Samuel" or "Betha" or "Akorede" or "Rasheed" or "Daniel" and password == "Accounting":
        welcomeMessage(username1)
    elif username2 == "Oshim" or "Daniel" or "Onyekachi" or "Shalom" or "Edward" or "Michael" or "Oluwadamilola" or "Boluwatife" or "Mary" or "Oluwafikunmi" or "Uchenna" and password == "Delivery":
        welcomeMessage(username2)
    elif username3 == "Jason" or "Otu" or "Onyinyechi" or "Raphael" or "Victor" or "Ejike" and password == "Administration":
        welcomeMessage(username3)
    else:
        messagebox.showerror("login","Invalid username or password ")

# Create main window
root = tk.Tk()
root.title("login form")
root.geometry("500x200")


# Create username label and entry
username_label = tk.Label(root, text="Firstname:")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

#create password label and entry
password_label = tk.Label(root, text="department:")
password_label.pack()
password_entry = tk.Entry(root, show="*")
password_entry.pack()

#create submit button
submit_button = tk.Button(root, text="Enter", command=submit)
submit_button.pack()

warning_1 = tk.Label(root, text="Please,start every word with capital letter")
warning_1.pack()


#run the main event loop
root.mainloop()
